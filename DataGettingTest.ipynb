# %%
import pandas as pd
from binance import Client
import binance.exceptions
import DataUtils
import datetime
import json

# %%
df = DataUtils.GetHistoricalPriceData('BTC')

# %%
df
# Out:
#          Open      High       Low     Close         Volume  \
# 0     4261.48   4485.39   3850.00   4086.29    2843.431426
# 1     4069.13   4453.91   3400.00   4310.01    4599.396629
# 2     4310.01   4939.19   4124.54   4509.08    4753.843376
# 3     4505.00   4788.59   3603.00   4130.37    6382.787745
# 4     4153.62   4394.59   2817.00   3699.99    8106.705127
# ..        ...       ...       ...       ...            ...
# 246  38468.35  40023.77  33713.95  34038.40  419979.582900
# 247  34038.39  34243.15  26700.00  31328.89  964223.849274
# 248  31328.89  31328.90  28654.47  30293.94  375096.223760
# 249  30293.93  30670.51  28019.56  29468.10  430508.719910
# 250  29468.10  32399.00  29282.36  29919.21  422401.403520
#
#                   Close time
# 0    2017-08-20 23:59:59.999
# 1    2017-08-27 23:59:59.999
# 2    2017-09-03 23:59:59.999
# 3    2017-09-10 23:59:59.999
# 4    2017-09-17 23:59:59.999
# ..                       ...
# 246  2022-05-08 23:59:59.999
# ...

# %%
[s.split(' ')[0] for s in df['Close time']]
# Out:
# ['2017-08-20',
#  '2017-08-27',
#  '2017-09-03',
#  '2017-09-10',
#  '2017-09-17',
#  '2017-09-24',
#  '2017-10-01',
#  '2017-10-08',
#  '2017-10-15',
#  '2017-10-22',
#  '2017-10-29',
#  '2017-11-05',
#  '2017-11-12',
#  '2017-11-19',
#  '2017-11-26',
#  '2017-12-03',
#  '2017-12-10',
#  '2017-12-17',
#  '2017-12-24',
#  '2017-12-31',
#  '2018-01-07',
#  '2018-01-14',
#  '2018-01-21',
#  '2018-01-28',
#  '2018-02-04',
#  '2018-02-11',
#  '2018-02-18',
#  '2018-02-25',
#  '2018-03-04',
#  '2018-03-11',
#  '2018-03-18',
#  '2018-03-25',
#  '2018-04-01',
#  '2018-04-08',
#  '2018-04-15',
#  '2018-04-22',
#  '2018-04-29',
#  '2018-05-06',
#  '2018-05-13',
#  '2018-05-20',
#  '2018-05-27',
#  '2018-06-03',
#  '2018-06-10',
#  '2018-06-17',
#  '2018-06-24',
#  '2018-07-01',
#  '2018-07-08',
#  '2018-07-15',
#  '2018-07-22',
#  '2018-07-29',
#  '2018-08-05',
#  '2018-08-12',
#  '2018-08-19',
#  '2018-08-26',
#  '2018-09-02',
#  '2018-09-09',
#  '2018-09-16',
#  '2018-09-23',
# ...

# %%
dates = [s.split(' ')[0] for s in dates]

# %%
dates
# Out:
# ['2017-08-20',
#  '2017-08-27',
#  '2017-09-03',
#  '2017-09-10',
#  '2017-09-17',
#  '2017-09-24',
#  '2017-10-01',
#  '2017-10-08',
#  '2017-10-15',
#  '2017-10-22',
#  '2017-10-29',
#  '2017-11-05',
#  '2017-11-12',
#  '2017-11-19',
#  '2017-11-26',
#  '2017-12-03',
#  '2017-12-10',
#  '2017-12-17',
#  '2017-12-24',
#  '2017-12-31',
#  '2018-01-07',
#  '2018-01-14',
#  '2018-01-21',
#  '2018-01-28',
#  '2018-02-04',
#  '2018-02-11',
#  '2018-02-18',
#  '2018-02-25',
#  '2018-03-04',
#  '2018-03-11',
#  '2018-03-18',
#  '2018-03-25',
#  '2018-04-01',
#  '2018-04-08',
#  '2018-04-15',
#  '2018-04-22',
#  '2018-04-29',
#  '2018-05-06',
#  '2018-05-13',
#  '2018-05-20',
#  '2018-05-27',
#  '2018-06-03',
#  '2018-06-10',
#  '2018-06-17',
#  '2018-06-24',
#  '2018-07-01',
#  '2018-07-08',
#  '2018-07-15',
#  '2018-07-22',
#  '2018-07-29',
#  '2018-08-05',
#  '2018-08-12',
#  '2018-08-19',
#  '2018-08-26',
#  '2018-09-02',
#  '2018-09-09',
#  '2018-09-16',
#  '2018-09-23',
# ...
